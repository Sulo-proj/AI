# %% [markdown]
# ## Import Modules and Data

# %%
import pandas as pd
import RFE_Classifications as rfe_class
import data_analysis_utils as utils
from sklearn.preprocessing import StandardScaler



inp_dataset = pd.read_csv('kidney_disease.csv')
inp_dataset = pd.read_csv('kidney_disease.csv').drop(columns='id')

inp_dataset
# Out:
#       age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0    48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1     7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2    62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3    48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4    51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
# ..    ...   ...    ...  ...  ...     ...       ...         ...         ...
# 395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
#
#        bgr  ...  pcv    wc   rc  htn   dm cad appet   pe  ane classification
# 0    121.0  ...   44  7800  5.2  yes  yes  no  good   no   no            ckd
# 1      NaN  ...   38  6000  NaN   no   no  no  good   no   no            ckd
# 2    423.0  ...   31  7500  NaN   no  yes  no  poor   no  yes            ckd
# 3    117.0  ...   32  6700  3.9  yes   no  no  poor  yes  yes            ckd
# 4    106.0  ...   35  7300  4.6   no   no  no  good   no   no            ckd
# ..     ...  ...  ...   ...  ...  ...  ...  ..   ...  ...  ...            ...
# 395  140.0  ...   47  6700  4.9   no   no  no  good   no   no         notckd
# 396   75.0  ...   54  7800  6.2   no   no  no  good   no   no         notckd
# 397  100.0  ...   49  6600  5.4   no   no  no  good   no   no         notckd
# 398  114.0  ...   51  7200  5.9   no   no  no  good   no   no         notckd
# 399  131.0  ...   53  6800  6.1   no   no  no  good   no   no         notckd
#
# [400 rows x 25 columns]

# %% [markdown]
# ## Analysing Raw data and Preprocess

# %%
print('Missing Value Percentages:', inp_dataset.isnull().mean()*100)

quan, qual = utils.Preprocessing.quanQual(inp_dataset)
inp_dataset = utils.Preprocessing.quanVariables(inp_dataset, qual)
inp_dataset[['pcv', 'rc', 'wc']]=inp_dataset[['pcv', 'rc', 'wc']].astype(float)
quan, qual = utils.Preprocessing.quanQual(inp_dataset)
inp_dataset = utils.Preprocessing.simple_missing(inp_dataset, quan, qual)
inp_dataset = utils.Preprocessing.model_missing(inp_dataset, quan)
# Out:
# Missing Value Percentages: age                2.25
# bp                 3.00
# sg                11.75
# al                11.50
# su                12.25
# rbc               38.00
# pc                16.25
# pcc                1.00
# ba                 1.00
# bgr               11.00
# bu                 4.75
# sc                 4.25
# sod               21.75
# pot               22.00
# hemo              13.00
# pcv               17.50
# wc                26.25
# rc                32.50
# htn                0.50
# dm                 0.50
# cad                0.50
# appet              0.25
# pe                 0.25
# ane                0.25
# classification     0.00
# dtype: float64

# %% [markdown]
# ## Scaled and encoded Input, Target variables split

# %%
quan_data = inp_dataset[quan]
quan_scaler = StandardScaler()
quan_scaled = quan_scaler.fit_transform(quan_data)
scaled_data = pd.DataFrame(quan_scaled, columns=quan)
scaled_data[qual] = inp_dataset[qual]

data = pd.get_dummies(scaled_data, drop_first=True)
indep_X = data.iloc[:, :-1]
dep_Y = data.iloc[:, -1]

# %% [markdown]
# ## Fearture Selection

# %%
# Step 1: Run RFE to reduce features (keeps DataFrame instead of NumPy arrays)

rfelist, features_list = rfe_class.rfeFeature(indep_X, dep_Y, n_features=3)

# Step 2: Run classifiers on RFE outputs + include features
result = rfe_class.rfe_classification(rfelist, features_list, dep_Y)

print("\nFinal Accuracy Table (with Features):")
result
# Out:
# Final Accuracy Table (with Features):
#    No_of_Features        RFE_Model        Selected_Features  Logistic  \
# 0               3      LogisticRFE   al, rbc_normal, dm_yes  0.955056
# 1               3           SVCRFE  al, rbc_normal, htn_yes  0.966292
# 2               3  RandomForestRFE     sc, hemo, rbc_normal  0.943820
# 3               3  DecisionTreeRFE       sg, rc, rbc_normal  0.910112
#
#        SVMl     SVMnl       KNN     Naive  Decision    Random
# 0  0.955056  0.955056  0.955056  0.898876  0.955056  0.955056
# 1  0.966292  0.966292  0.966292  0.887640  0.966292  0.966292
# 2  0.943820  0.943820  0.932584  0.831461  0.921348  0.932584
# 3  0.910112  0.910112  0.898876  0.719101  0.898876  0.876404

# %%
fullresult = pd.DataFrame()
for n in range(3,7):
    rfelist, features_list = rfe_class.rfeFeature(indep_X, dep_Y, n_features=n)

    # Step 2: Run classifiers on RFE outputs + include features
    result = rfe_class.rfe_classification(rfelist, features_list, dep_Y)
    fullresult = pd.concat([fullresult, result], ignore_index=True)


fullresult
# Out:
#     No_of_Features        RFE_Model  \
# 0                3      LogisticRFE
# 1                3           SVCRFE
# 2                3  RandomForestRFE
# 3                3  DecisionTreeRFE
# 4                4      LogisticRFE
# 5                4           SVCRFE
# 6                4  RandomForestRFE
# 7                4  DecisionTreeRFE
# 8                5      LogisticRFE
# 9                5           SVCRFE
# 10               5  RandomForestRFE
# 11               5  DecisionTreeRFE
# 12               6      LogisticRFE
# 13               6           SVCRFE
# 14               6  RandomForestRFE
# 15               6  DecisionTreeRFE
#
#                                     Selected_Features  Logistic      SVMl  \
# 0                              al, rbc_normal, dm_yes  0.955056  0.955056
# 1                             al, rbc_normal, htn_yes  0.966292  0.966292
# 2                                sc, hemo, rbc_normal  0.943820  0.943820
# 3                                  sg, rc, rbc_normal  0.910112  0.910112
# 4                     al, rbc_normal, htn_yes, dm_yes  0.977528  0.955056
# 5                 al, rbc_normal, htn_yes, appet_poor  0.966292  0.966292
# 6                       sc, hemo, rbc_normal, htn_yes  0.977528  0.932584
# 7                         sg, rc, rbc_normal, htn_yes  0.966292  0.921348
# 8         al, rbc_normal, htn_yes, dm_yes, appet_poor  0.977528  0.966292
# 9             al, sc, rbc_normal, htn_yes, appet_poor  0.988764  0.988764
# 10                 sc, hemo, pcv, rbc_normal, htn_yes  0.988764  0.955056
# 11                    sg, bu, rc, rbc_normal, htn_yes  0.932584  0.943820
# 12  al, rbc_normal, pc_normal, htn_yes, dm_yes, ap...  0.966292  0.977528
# 13    al, sc, rbc_normal, htn_yes, appet_poor, pe_yes  0.988764  0.988764
# 14             sg, sc, hemo, pcv, rbc_normal, htn_yes  0.977528  0.966292
# 15         sg, bu, rc, rbc_normal, pc_normal, htn_yes  0.943820  0.943820
#
#        SVMnl       KNN     Naive  Decision    Random
# 0   0.955056  0.955056  0.898876  0.955056  0.955056
# 1   0.966292  0.966292  0.887640  0.966292  0.966292
# 2   0.943820  0.932584  0.831461  0.921348  0.932584
# 3   0.910112  0.898876  0.719101  0.898876  0.876404
# 4   0.977528  0.977528  0.932584  0.977528  0.977528
# 5   0.966292  0.966292  0.921348  0.966292  0.966292
# 6   0.943820  0.943820  0.921348  0.966292  0.977528
# 7   0.966292  0.932584  0.820225  0.955056  0.977528
# 8   0.977528  0.966292  0.955056  0.966292  0.977528
# 9   0.977528  0.977528  0.977528  0.966292  0.977528
# 10  0.955056  0.955056  0.921348  0.966292  0.977528
# 11  0.955056  0.932584  0.865169  0.966292  0.977528
# 12  0.977528  0.966292  0.966292  0.966292  0.977528
# 13  0.977528  0.977528  0.988764  0.966292  0.988764
# 14  0.966292  0.966292  0.921348  0.966292  1.000000
# 15  0.955056  0.932584  0.876404  0.966292  0.988764

# %%
max_val = fullresult.iloc[:, 3:].values.max()
row, col = fullresult.iloc[:, 3:].stack().idxmax()
no_features = fullresult.iloc[row, 0]
features = fullresult.iloc[row,2]
rfe_model = fullresult.iloc[row,1]
print(f'Max Accuracy is: {max_val:.4f}% for {rfe_model} Model and {col} Model  \nWith No of Features = {no_features}, Selected Features: {features}')
# Out:
# Max Accuracy is: 1.0000% for RandomForestRFE Model and Random Model
# With No of Features = 6, Selected Features: sg, sc, hemo, pcv, rbc_normal, htn_yes
