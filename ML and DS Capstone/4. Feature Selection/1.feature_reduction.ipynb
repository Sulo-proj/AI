# %%
import pickle
import numpy as np
import sys
sys.path.append(r"D:\HopeAI\Assignments\MyModules")
from data_analysis_utils import Preprocessing

# %%
# dataset = pd.read_csv(r"D:\HopeAI\Assignments\ML and DS Capstone\2. Data Preprocessing\PreStockFeatures.csv")
filename=r'D:\HopeAI\Assignments\ML and DS Capstone\2. Data Preprocessing\pre_dataset.pkl'
dataset = pickle.load( open(filename,'rb'))

quan, _ = Preprocessing.quanQual(dataset)

dataset
# Out:
#         Stock      Sector                         Industry     Market Cap  \
# 0    ADANIENT      Energy                     Thermal Coal  2994291081216
# 1    ADANIENT      Energy                     Thermal Coal  2994291081216
# 2    ADANIENT      Energy                     Thermal Coal  2994291081216
# 3    ADANIENT      Energy                     Thermal Coal  2994291081216
# 4    ADANIENT      Energy                     Thermal Coal  2994291081216
# ..        ...         ...                              ...            ...
# 497     WIPRO  Technology  Information Technology Services  2532097654784
# 498     WIPRO  Technology  Information Technology Services  2532097654784
# 499     WIPRO  Technology  Information Technology Services  2532097654784
# 500     WIPRO  Technology  Information Technology Services  2532097654784
# 501     WIPRO  Technology  Information Technology Services  2532097654784
#
#      Year  Total_Annual_Return  Avg_Monthly_Return  Std_Monthly_Return  \
# 0    2014            84.785613            7.637515           14.186042
# 1    2015           -37.685498           -3.887377           19.560876
# 2    2016           -14.119856            1.611336           15.492383
# 3    2017           117.329561            6.434280            8.526439
# 4    2018            78.500944            5.578514           26.632411
# ..    ...                  ...                 ...                 ...
# 497  2020            56.564122            5.078310           11.196238
# 498  2021            84.735387            5.200053            6.752821
# 499  2022           -44.808074           -3.105960            6.336069
# 500  2023            20.203754            1.701905            6.272716
# 501  2024            27.568983            2.404619            6.886506
#
#      Max_Drawdown  Std_Daily_Return  Pos_Days_Pct  Neg_Days_Pct  Avg_Daily_TR  \
# 0       22.867706          3.010790     52.674897     46.090535      2.352871
# 1       68.997003          4.156785     45.714286     52.653061      3.742656
# 2       34.794663          2.639648     53.469388     45.306122      1.581010
# 3       28.780005          3.281672     56.680162     42.510121      2.889061
# 4       43.633455          3.637141     54.693878     45.306122      6.293391
# ..            ...               ...           ...           ...           ...
# 497     36.623083          2.500823     52.000000     47.200000      3.742075
# 498     12.734524          1.763293     57.085020     42.914980      6.545712
# 499     47.492937          1.706648     47.368421     52.631579      4.864650
# 500     14.238744          1.237919     48.360656     51.229508      3.161690
# 501     19.530389          1.765686     49.590164     49.180328      5.841738
#
#      Max_Daily_TR    Avg_Volume  Volume_Spike_Pct  12M_Momentum  \
# 0       13.486429  1.861417e+07          8.196721    107.917632
# 1      239.273886  1.120364e+07          7.317073    -51.324566
# 2        4.432787  6.074467e+06          6.097561      6.215522
# 3       19.576553  1.295658e+07          8.064516     91.893377
# 4       30.900989  1.475299e+07         11.382114     39.024769
# ..            ...           ...               ...           ...
# 497     16.643016  2.239159e+07          9.163347     63.112320
# 498     21.253327  2.143325e+07         10.080645     71.177270
# 499     17.585685  1.479087e+07          3.629032    -30.838344
# 500     15.496817  1.015820e+07          6.938776     18.164716
# 501     19.119149  1.613829e+07          6.122449     27.031270
#
#      Months_Pos_Pct  Beta_vs_NIFTY  Corr_with_NIFTY
# 0         63.636364       1.598832         0.426155
# 1         54.545455       1.850348         0.457929
# 2         54.545455       1.649825         0.597262
# 3         81.818182       1.912510         0.332076
# 4         36.363636       2.142941         0.478182
# ..              ...            ...              ...
# 497       63.636364       0.670407         0.529060
# 498       72.727273       0.849918         0.476230
# 499       27.272727       1.083736         0.691712
# 500       54.545455       1.108324         0.554158
# 501       72.727273       1.057317         0.532694
#
# [484 rows x 20 columns]

# %% [markdown]
# ## Remove Highly Correlated Features

# %%
data_corr=dataset[quan].corr()
data_corr.corr()
# Out:
#                      Market Cap      Year  Total_Annual_Return  \
# Market Cap             1.000000 -0.002218            -0.143281
# Year                  -0.002218  1.000000            -0.105726
# Total_Annual_Return   -0.143281 -0.105726             1.000000
# Avg_Monthly_Return    -0.166544 -0.128989             0.992723
# Std_Monthly_Return    -0.422653 -0.337147            -0.101593
# Max_Drawdown          -0.229058 -0.193494            -0.701351
# Std_Daily_Return      -0.414698 -0.378383            -0.209109
# Pos_Days_Pct           0.020242  0.116904             0.831580
# Neg_Days_Pct          -0.007426 -0.081952            -0.848322
# Avg_Daily_TR          -0.139825  0.496537            -0.146443
# Max_Daily_TR          -0.195996  0.448584            -0.172960
# Avg_Volume             0.118863 -0.168889            -0.147818
# Volume_Spike_Pct      -0.618654 -0.264041             0.364464
# 12M_Momentum          -0.150976 -0.128521             0.997865
# Months_Pos_Pct        -0.060576 -0.017828             0.933641
# Beta_vs_NIFTY         -0.018309 -0.265959            -0.241928
# Corr_with_NIFTY        0.350812  0.046146            -0.486663
#
#                      Avg_Monthly_Return  Std_Monthly_Return  Max_Drawdown  \
# Market Cap                    -0.166544           -0.422653     -0.229058
# Year                          -0.128989           -0.337147     -0.193494
# Total_Annual_Return            0.992723           -0.101593     -0.701351
# Avg_Monthly_Return             1.000000           -0.008146     -0.633706
# Std_Monthly_Return            -0.008146            1.000000      0.768704
# Max_Drawdown                  -0.633706            0.768704      1.000000
# Std_Daily_Return              -0.120357            0.972715      0.835350
# Pos_Days_Pct                   0.830965           -0.085491     -0.580993
# Neg_Days_Pct                  -0.849714            0.065153      0.576615
# Avg_Daily_TR                  -0.188334           -0.339249     -0.159047
# Max_Daily_TR                  -0.205372           -0.225930     -0.058896
# Avg_Volume                    -0.086395            0.488480      0.437982
# Volume_Spike_Pct               0.364278            0.235508     -0.060709
# 12M_Momentum                   0.995086           -0.086797     -0.689640
# Months_Pos_Pct                 0.927183           -0.253881     -0.759226
# Beta_vs_NIFTY                 -0.168683            0.639464      0.616898
# Corr_with_NIFTY               -0.433274            0.321551      0.536996
#
#                      Std_Daily_Return  Pos_Days_Pct  Neg_Days_Pct  \
# Market Cap                  -0.414698      0.020242     -0.007426
# Year                        -0.378383      0.116904     -0.081952
# Total_Annual_Return         -0.209109      0.831580     -0.848322
# Avg_Monthly_Return          -0.120357      0.830965     -0.849714
# Std_Monthly_Return           0.972715     -0.085491      0.065153
# Max_Drawdown                 0.835350     -0.580993      0.576615
# Std_Daily_Return             1.000000     -0.206269      0.185407
# Pos_Days_Pct                -0.206269      1.000000     -0.998873
# Neg_Days_Pct                 0.185407     -0.998873      1.000000
# Avg_Daily_TR                -0.352900     -0.048940      0.084470
# Max_Daily_TR                -0.231944     -0.068615      0.102330
# Avg_Volume                   0.501685     -0.042203      0.023381
# Volume_Spike_Pct             0.203638      0.101980     -0.124909
# 12M_Momentum                -0.191603      0.809837     -0.828249
# Months_Pos_Pct              -0.344102      0.839881     -0.850792
# Beta_vs_NIFTY                0.720338     -0.205069      0.191929
# Corr_with_NIFTY              0.389495     -0.258075      0.267820
#
#                      Avg_Daily_TR  Max_Daily_TR  Avg_Volume  Volume_Spike_Pct  \
# Market Cap              -0.139825     -0.195996    0.118863         -0.618654
# Year                     0.496537      0.448584   -0.168889         -0.264041
# Total_Annual_Return     -0.146443     -0.172960   -0.147818          0.364464
# Avg_Monthly_Return      -0.188334     -0.205372   -0.086395          0.364278
# Std_Monthly_Return      -0.339249     -0.225930    0.488480          0.235508
# Max_Drawdown            -0.159047     -0.058896    0.437982         -0.060709
# Std_Daily_Return        -0.352900     -0.231944    0.501685          0.203638
# Pos_Days_Pct            -0.048940     -0.068615   -0.042203          0.101980
# Neg_Days_Pct             0.084470      0.102330    0.023381         -0.124909
# Avg_Daily_TR             1.000000      0.988716   -0.644692         -0.126177
# Max_Daily_TR             0.988716      1.000000   -0.609607         -0.082159
# Avg_Volume              -0.644692     -0.609607    1.000000         -0.219449
# Volume_Spike_Pct        -0.126177     -0.082159   -0.219449          1.000000
# 12M_Momentum            -0.165946     -0.191286   -0.137087          0.368954
# Months_Pos_Pct          -0.083402     -0.121834   -0.181890          0.239644
# Beta_vs_NIFTY           -0.317326     -0.229827    0.502402         -0.238867
# Corr_with_NIFTY         -0.082233     -0.045442    0.408648         -0.653667
#
#                      12M_Momentum  Months_Pos_Pct  Beta_vs_NIFTY  \
# Market Cap              -0.150976       -0.060576      -0.018309
# Year                    -0.128521       -0.017828      -0.265959
# Total_Annual_Return      0.997865        0.933641      -0.241928
# Avg_Monthly_Return       0.995086        0.927183      -0.168683
# Std_Monthly_Return      -0.086797       -0.253881       0.639464
# Max_Drawdown            -0.689640       -0.759226       0.616898
# Std_Daily_Return        -0.191603       -0.344102       0.720338
# Pos_Days_Pct             0.809837        0.839881      -0.205069
# Neg_Days_Pct            -0.828249       -0.850792       0.191929
# Avg_Daily_TR            -0.165946       -0.083402      -0.317326
# Max_Daily_TR            -0.191286       -0.121834      -0.229827
# Avg_Volume              -0.137087       -0.181890       0.502402
# Volume_Spike_Pct         0.368954        0.239644      -0.238867
# 12M_Momentum             1.000000        0.933118      -0.219190
# Months_Pos_Pct           0.933118        1.000000      -0.321036
# Beta_vs_NIFTY           -0.219190       -0.321036       1.000000
# Corr_with_NIFTY         -0.475416       -0.467590       0.794796
#
#                      Corr_with_NIFTY
# Market Cap                  0.350812
# Year                        0.046146
# Total_Annual_Return        -0.486663
# Avg_Monthly_Return         -0.433274
# Std_Monthly_Return          0.321551
# Max_Drawdown                0.536996
# Std_Daily_Return            0.389495
# Pos_Days_Pct               -0.258075
# Neg_Days_Pct                0.267820
# Avg_Daily_TR               -0.082233
# Max_Daily_TR               -0.045442
# Avg_Volume                  0.408648
# Volume_Spike_Pct           -0.653667
# 12M_Momentum               -0.475416
# Months_Pos_Pct             -0.467590
# Beta_vs_NIFTY               0.794796
# Corr_with_NIFTY             1.000000

# %%
corr_matrix = dataset[quan].corr().abs()  # Absolute correlations
upper_triangle = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# Find columns to drop with correlation > 0.75
to_drop = [column for column in upper_triangle.columns if any(upper_triangle[column] > 0.75)]

print("Features to remove:", to_drop)
# Out:
# Features to remove: ['Avg_Monthly_Return', 'Std_Daily_Return', 'Neg_Days_Pct', 'Max_Daily_TR', '12M_Momentum']

# %% [markdown]
# ## Remove the Unnecessary Columns

# %%
dataset_reduced = dataset.drop(columns=to_drop)
dataset_reduced.columns
# Out:
# Index(['Stock', 'Sector', 'Industry', 'Market Cap', 'Year',
#        'Total_Annual_Return', 'Std_Monthly_Return', 'Max_Drawdown',
#        'Pos_Days_Pct', 'Avg_Daily_TR', 'Avg_Volume', 'Volume_Spike_Pct',
#        'Months_Pos_Pct', 'Beta_vs_NIFTY', 'Corr_with_NIFTY'],
#       dtype='object')

# %%
filename="dataset_reduced.pkl"
pickle.dump(dataset_reduced, open(filename,'wb'))

cols_to_drop = ['Stock', 'Sector', 'Industry', 'Year']
dataset_unscaled = dataset_reduced.drop(cols_to_drop, axis=1)
filename="dataset_unscaled.pkl"
pickle.dump(dataset_unscaled, open(filename,'wb'))
dataset_unscaled
# Out:
#         Market Cap  Total_Annual_Return  Std_Monthly_Return  Max_Drawdown  \
# 0    2994291081216            84.785613           14.186042     22.867706
# 1    2994291081216           -37.685498           19.560876     68.997003
# 2    2994291081216           -14.119856           15.492383     34.794663
# 3    2994291081216           117.329561            8.526439     28.780005
# 4    2994291081216            78.500944           26.632411     43.633455
# ..             ...                  ...                 ...           ...
# 497  2532097654784            56.564122           11.196238     36.623083
# 498  2532097654784            84.735387            6.752821     12.734524
# 499  2532097654784           -44.808074            6.336069     47.492937
# 500  2532097654784            20.203754            6.272716     14.238744
# 501  2532097654784            27.568983            6.886506     19.530389
#
#      Pos_Days_Pct  Avg_Daily_TR    Avg_Volume  Volume_Spike_Pct  \
# 0       52.674897      2.352871  1.861417e+07          8.196721
# 1       45.714286      3.742656  1.120364e+07          7.317073
# 2       53.469388      1.581010  6.074467e+06          6.097561
# 3       56.680162      2.889061  1.295658e+07          8.064516
# 4       54.693878      6.293391  1.475299e+07         11.382114
# ..            ...           ...           ...               ...
# 497     52.000000      3.742075  2.239159e+07          9.163347
# 498     57.085020      6.545712  2.143325e+07         10.080645
# 499     47.368421      4.864650  1.479087e+07          3.629032
# 500     48.360656      3.161690  1.015820e+07          6.938776
# 501     49.590164      5.841738  1.613829e+07          6.122449
#
#      Months_Pos_Pct  Beta_vs_NIFTY  Corr_with_NIFTY
# 0         63.636364       1.598832         0.426155
# 1         54.545455       1.850348         0.457929
# 2         54.545455       1.649825         0.597262
# 3         81.818182       1.912510         0.332076
# 4         36.363636       2.142941         0.478182
# ..              ...            ...              ...
# 497       63.636364       0.670407         0.529060
# 498       72.727273       0.849918         0.476230
# 499       27.272727       1.083736         0.691712
# 500       54.545455       1.108324         0.554158
# 501       72.727273       1.057317         0.532694
#
# [484 rows x 11 columns]
