# %% [markdown]
# # 1.OS Error

# %%
pip install spaCy
# Out:
# ...
#    ---------------------------------------- 0.0/15.3 MB ? eta -:--:--
#    --------------- ------------------------ 5.8/15.3 MB 32.0 MB/s eta 0:00:01
#    ------------------------- -------------- 10.0/15.3 MB 24.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.1/15.3 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  15.2/15.3 MB 20.8 MB/s eta 0:00:01
#    ---------------------------------------- 15.3/15.3 MB 15.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 18.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/654.0 kB ? eta -:--:--
#    ---------------------------------------- 654.0/654.0 kB 12.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 1.8/1.8 MB 14.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
# ...

# %%
import spacy
import os

# Download the model first if not available
os.system("python -m spacy download en_core_web_sm")

# Then load
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# # 2.Error: ModuleNotFoundError for TextBlob

# %%
pip install textblob
# Out:
# ...
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    ---------------------------------------- 624.3/624.3 kB 11.3 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from textblob import TextBlob
blob = TextBlob("TextBlob is amazing.")

# %% [markdown]
# # 3.AttributeError

# %%
from sklearn.feature_extraction.text import CountVectorizer
texts = ['123', '456']  # numeric values instead of strings
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(texts)
print(X.toarray())
# Out:
# [[1 0]
#  [0 1]]

# %% [markdown]
# # 4.Attribute Error

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english') # words - not word

# %% [markdown]
# # 5.ValueError

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()
text = ["single string"," instead of list"] # should be list of strings, not single string
X = tfidf.fit_transform(text)

# %% [markdown]
# # 6.NameError

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud, STOPWORDS # import STOPWORDS to use it
wc = WordCloud(stopwords=STOPWORDS)
