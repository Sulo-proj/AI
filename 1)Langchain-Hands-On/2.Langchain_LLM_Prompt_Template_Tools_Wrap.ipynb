# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import PromptTemplate
# from langchain_classic.chains import LLMChain
from langchain_classic.tools import Tool


# 🔸 Step 1: Initialize the LLM
llm = ChatOllama(model="mistral", 
                 temperature=0)

# 🔸 Step 2: Create a prompt template
prompt = PromptTemplate.from_template("Answer clearly: {question}")

# 🔸 Step 3: Build the LLMChain
# qa_chain = LLMChain(llm=llm, prompt=prompt)
qa_chain = prompt | llm

# 🔸 Step 4: Wrap LLMChain as a Tool
qa_tool = Tool(
    name="Simple QA",
    func=qa_chain.invoke,
    description="A basic LLM chain that clearly answers the questions"
)

# 🔸 Step 5: Use the Tool directly
query = "What is LangGraph in LangChain?"
answer = qa_tool.run(query)

# 🖨️ Output
print("\nUser Question:", query)
print("\nTool Answer:", answer)
# Out:
# User Question: What is LangGraph in LangChain?
#
# Tool Answer: content=" LangGraph, in the context of LangChain, is a component or a model within the LangChain ecosystem. It's a graph-based language model that uses a graph neural network (GNN) architecture. The primary purpose of LangGraph is to understand and generate text by modeling the relationships between words and phrases in a more nuanced way than traditional language models. This approach allows LangGraph to better capture the semantic and syntactic structures of language, potentially leading to more contextually aware and coherent text generation. However, it's important to note that specific details about LangGraph may vary depending on the exact implementation within different LangChain projects." additional_kwargs={} response_metadata={'model': 'mistral', 'created_at': '2026-03-12T04:51:55.3151232Z', 'done': True, 'done_reason': 'stop', 'total_duration': 16611314000, 'load_duration': 41850800, 'prompt_eval_count': 15, 'prompt_eval_duration': 370820300, 'eval_count': 133, 'eval_duration': 15652763000, 'logprobs': None, 'model_name': 'mistral', 'model_provider': 'ollama'} id='lc_run--019ce062-d24e-7c23-892d-524d7482a7d7-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 15, 'output_tokens': 133, 'total_tokens': 148}
