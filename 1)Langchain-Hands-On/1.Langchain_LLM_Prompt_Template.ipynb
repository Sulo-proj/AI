# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import PromptTemplate
from langchain_classic.chains import LLMChain

llm = ChatOllama(
    model="mistral",
    temperature=0.2)

prompt = PromptTemplate.from_template(
    "Explain clearly: {question}"
)

chain = prompt | llm

query = "What is LangGraph in LangChain?"

response = chain.invoke({
    "question": query
})

print("\nUser Question:", query)
print("\nLLM Answer:", response.content)
# Out:
# User Question: What is LangGraph in LangChain?
#
# LLM Answer:  LangGraph, in the context of LangChain, is a graph-based language model. It's a key component of LangChain, a platform designed to create, train, and deploy large-scale language models.
#
# LangGraph is unique because it uses a graph structure to represent the relationships between words, phrases, and sentences. This structure allows the model to understand the context and semantics of language more effectively, as it can capture complex patterns and dependencies that might be missed by traditional linear models.
#
# In essence, LangGraph is a powerful tool for natural language processing tasks, such as text generation, translation, summarization, and question answering, due to its ability to understand the intricate nuances of language. However, it's important to note that while I mentioned LangChain, I didn't provide specific details about the exact implementation of LangGraph within LangChain, as I don't have real-time access to the latest developments in their research.
