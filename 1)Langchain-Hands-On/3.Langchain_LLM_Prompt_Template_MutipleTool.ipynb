# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import PromptTemplate
from langchain_classic.tools import Tool


# 🔸 Initialize the LLM
llm = ChatOllama(model="mistral", 
                 temperature=0)

# ✅ Tool 1: Simple QA Tool
qa_prompt = PromptTemplate.from_template("Answer clearly: {question}")
qa_chain = qa_prompt | llm
qa_tool = Tool(
    name="Simple QA",
    func=qa_chain.invoke,
    description="Answer factual questions clearly"
)

# ✅ Tool 2: Summarizer Tool
summary_prompt = PromptTemplate.from_template("Summarize the following text:\n\n{text}")
summary_chain = summary_prompt | llm
summary_tool = Tool(
    name="Summarizer",
    func=summary_chain.invoke,
    description="Summarizes input text"
)

# 🔧 Tool usage examples
qa_query = "What is LangGraph in LangChain?"
summary_text = """
LangGraph is a library built on top of LangChain that helps developers create stateful, multi-step agents 
as graphs. Each node represents a step like calling an LLM or a tool. It's ideal for advanced AI workflows.
"""

# 🚀 Run tools manually
print("\n🧠 Simple QA Tool Output:\n", qa_tool.run({"question": qa_query}))
print("\n📝 Summarizer Tool Output:\n", summary_tool.run({"text": summary_text}))
# Out:
# 🧠 Simple QA Tool Output:
#  content=" LangGraph, in the context of LangChain, is a component or a model within the LangChain ecosystem. It's a graph-based language model that uses a graph neural network (GNN) architecture. The primary purpose of LangGraph is to understand and generate text by modeling the relationships between words and phrases in a more nuanced way than traditional language models. This allows it to better capture the semantic meaning and context of the text, improving its performance in tasks such as question answering, summarization, and text generation. However, it's important to note that I don't have real-time access to specific details about LangChain or LangGraph, so this information is based on publicly available information." additional_kwargs={} response_metadata={'model': 'mistral', 'created_at': '2026-03-12T04:59:16.1331718Z', 'done': True, 'done_reason': 'stop', 'total_duration': 23096940400, 'load_duration': 3226125600, 'prompt_eval_count': 15, 'prompt_eval_duration': 896448700, 'eval_count': 146, 'eval_duration': 18458370900, 'logprobs': None, 'model_name': 'mistral', 'model_provider': 'ollama'} id='lc_run--019ce069-72e2-7ab1-8ff3-3e428f3f023f-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 15, 'output_tokens': 146, 'total_tokens': 161}
#
# 📝 Summarizer Tool Output:
#  content=' LangGraph is a library developed on top of LangChain. It allows developers to create complex, multi-step AI workflows as graphs, where each node represents a step such as calling a Language Model (LLM) or a tool. This system is particularly useful for advanced AI applications.' additional_kwargs={} response_metadata={'model': 'mistral', 'created_at': '2026-03-12T04:59:25.5181469Z', 'done': True, 'done_reason': 'stop', 'total_duration': 9380262300, 'load_duration': 35920500, 'prompt_eval_count': 67, 'prompt_eval_duration': 911809100, 'eval_count': 60, 'eval_duration': 8356516400, 'logprobs': None, 'model_name': 'mistral', 'model_provider': 'ollama'} id='lc_run--019ce069-cd28-70f0-8e04-2eff5132c86a-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 67, 'output_tokens': 60, 'total_tokens': 127}
