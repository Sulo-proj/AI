# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import PromptTemplate
from langchain_classic.tools import Tool
from langchain_community.tools import DuckDuckGoSearchResults

# 🔸 Initialize LLM
llm = ChatOllama(
    model="mistral", 
    temperature=0)

# ✅ Tool 1: Simple QA
qa_prompt = PromptTemplate.from_template("Answer clearly: {question}")
qa_chain = qa_prompt | llm
qa_tool = Tool(
    name="Simple QA",
    func=qa_chain.invoke,
    description="Answer factual questions clearly"
)

# ✅ Tool 2: Summarizer
summary_prompt = PromptTemplate.from_template("Summarize the following text:\n\n{text}")
summary_chain = summary_prompt | llm
summary_tool = Tool(
    name="Summarizer",
    func=summary_chain.invoke,
    description="Summarizes input text"
)

# ✅ Tool 3: Web Search (Tavily)
search_tool = Tool(
    name="Web Search",
    func=DuckDuckGoSearchResults(num_results=3, output_format='list').invoke,
    description="Search the internet for current information"
)

# 🧪 Run each tool manually
qa_query = "What is LangGraph in LangChain?"
summary_text = """
LangGraph is a framework for building stateful multi-step agents using LangChain. 
It uses graph-based design to model agent workflows and memory.
"""
search_query = "Latest updates on Langchain"

print("\n🧠 Simple QA Tool Output:\n", qa_tool.run({"question": qa_query}).content)
print("\n📝 Summarizer Tool Output:\n", summary_tool.run({"text": summary_text}).content)
print("\n🌐 Web Search Tool Output:")
for i, result in enumerate(search_tool.run(search_query)):
    print(f"{i+1} Title: {result['title']} \nSnippet:\n {result['snippet']}")
# Out:
# 🧠 Simple QA Tool Output:
#   LangGraph, in the context of LangChain, is a component or a model within the LangChain ecosystem. It's a graph-based language model that uses a graph neural network (GNN) architecture. The primary purpose of LangGraph is to understand and generate text by modeling the relationships between words and phrases in a more nuanced and contextually aware manner compared to traditional language models.
#
# In simpler terms, LangGraph is designed to understand the structure and semantics of language more effectively, which can lead to more human-like and contextually appropriate text generation. However, for the most accurate and detailed information, I would recommend referring to the official LangChain documentation or reaching out to the LangChain team directly.
#
# 📝 Summarizer Tool Output:
#   LangGraph is a framework that utilizes LangChain to construct stateful multi-step agents. It employs a graph-based design to model agent workflows and memory, allowing for the creation of complex, multi-step AI agents.
#
# 🌐 Web Search Tool Output:
#
# 1 Title: LangChain - Changelog
# Snippet:
#  19 Feb 2026·Check out the latest product updates on the LangChain LaunchNotes page.
# 2 Title: Updated Langchain Version V1 Crash Course- Build Autonomous Agents - YouTube
# Snippet:
#  22 Dec 2025·... : AI Vulnerabilities Exposed. IBM Technology. New. 32K views · 53:20 · Go to channel NeuralNine · LangChain Full Crash Course - AI Agents in Python. NeuralNine ...
# 3 Title: LangChain and LangGraph Agent Frameworks Reach v1.0 Milestones
# Snippet:
#  22 Oct 2025·After years of feedback, we've updated langchain to focus on the core agent loop, provide flexibility with a new concept of middleware, and upgrade model ...
