# %%
import pandas as pd
from data_analysis_utils import Univariate
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('Placement.csv')
data.drop(columns = 'sl_no', axis = 1, inplace = True)

quan, qual = Univariate.quanQual(data)

print(quan, qual)
# Out:
# ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'] ['gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation', 'status']

# %% [markdown]
# # Central Tendency and Location of Data
#
# ### Mean, Mode, Median, Percentile, IQR

# %%
descriptive = Univariate.descriptive(data, quan)

print(descriptive)
# Out:
#                    ssc_p    hsc_p degree_p  etest_p   mba_p          salary
# Mean                67.3    66.33    66.37     72.1   62.28       288655.41
# Mode                62.0     63.0     65.0     60.0    56.7        300000.0
# Min                40.89     37.0     50.0     50.0   51.21        200000.0
# Q1-25th%            60.6     60.9     61.0     60.0  57.945        240000.0
# Median / Q2-50%     67.0     65.0     66.0     71.0    62.0        265000.0
# Q3-75th%            75.7     73.0     72.0     83.5  66.255        300000.0
# 99th%               87.0    91.86    83.86     97.0   76.11             NaN
# Max-100th%          89.4     97.7     91.0     98.0   77.89        940000.0
# IQR                 15.1     12.1     11.0     23.5    8.31         60000.0
# 1.5rule            22.65    18.15     16.5    35.25  12.465         90000.0
# LesserRange        37.95    42.75     44.5    24.75   45.48        150000.0
# GreaterRange       98.35    91.15     88.5   118.75   78.72        390000.0
# Skew               -0.37     -0.4    -0.83     0.12    -1.2             2.3
# Kurtosis           -0.74    -0.84    -0.49    -0.57   -0.29            5.98
# Var              1079.45  1138.79  1035.02  1343.91   855.3  58471812235.25
# Std                267.0    283.0    256.0    334.0   211.0   15627182883.0

# %%
descriptive, lesser, greater = Univariate.detect_outliers(descriptive, quan)

print(lesser, greater)
# Out:
# ['hsc_p'] ['hsc_p', 'degree_p', 'salary']

# %%
data = Univariate.remove_outliers(descriptive, data, lesser, greater)

# %%
descriptive_after_change = Univariate.descriptive(data, quan)

descriptive_after_change, lesser, greater = Univariate.detect_outliers(descriptive_after_change, quan)

print(lesser, greater)
# Out:
# [] []

# %%
for columnName in data.columns:
    freqTable = Univariate.freqTable(data, columnName)
    print(f'Frequency Table for {columnName}:\n{freqTable.head()}\n')
# Out:
# Frequency Table for gender:
#   UniqueValues  Frequency  RelativeFrequency%  Cumsum%
# 0            M        139               64.65    64.65
# 1            F         76               35.35   100.00
#
# Frequency Table for ssc_p:
#    UniqueValues  Frequency  RelativeFrequency%  Cumsum%
# 0          62.0         11                5.12     5.12
# 1          63.0         10                4.65     9.77
# 2          67.0          9                4.19    13.96
# 3          73.0          9                4.19    18.15
# 4          52.0          9                4.19    22.34
#
# Frequency Table for ssc_b:
#   UniqueValues  Frequency  RelativeFrequency%  Cumsum%
# 0      Central        116               53.95    53.95
# 1       Others         99               46.05   100.00
#
# Frequency Table for hsc_p:
#    UniqueValues  Frequency  RelativeFrequency%  Cumsum%
# 0          63.0         14                6.51     6.51
# 1          62.0         12                5.58    12.09
# 2          67.0          9                4.19    16.28
# 3          60.0          9                4.19    20.47
# 4          70.0          8                3.72    24.19
#
# Frequency Table for hsc_b:
#   UniqueValues  Frequency  RelativeFrequency%  Cumsum%
# 0       Others        131               60.93    60.93
# 1      Central         84               39.07   100.00
#
# Frequency Table for hsc_s:
#   UniqueValues  Frequency  RelativeFrequency%  Cumsum%
# 0     Commerce        113               52.56    52.56
# 1      Science         91               42.33    94.89
# 2         Arts         11                5.12   100.01
#
# Frequency Table for degree_p:
#    UniqueValues  Frequency  RelativeFrequency%  Cumsum%
# 0          65.0         20                9.30     9.30
# 1          66.0         13                6.05    15.35
# 2          72.0         12                5.58    20.93
# 3          64.0         11                5.12    26.05
# 4          58.0          9                4.19    30.24
#
# Frequency Table for degree_t:
#   UniqueValues  Frequency  RelativeFrequency%  Cumsum%
# 0    Comm&Mgmt        145               67.44    67.44
# 1     Sci&Tech         59               27.44    94.88
# 2       Others         11                5.12   100.00
#
# Frequency Table for workex:
#   UniqueValues  Frequency  RelativeFrequency%  Cumsum%
# 0           No        141               65.58    65.58
# 1          Yes         74               34.42   100.00
#
# Frequency Table for etest_p:
#    UniqueValues  Frequency  RelativeFrequency%  Cumsum%
# 0          60.0         14                6.51     6.51
# 1          80.0          8                3.72    10.23
# 2          67.0          7                3.26    13.49
# 3          75.0          7                3.26    16.75
# 4          89.0          6                2.79    19.54
#
# Frequency Table for specialisation:
#   UniqueValues  Frequency  RelativeFrequency%  Cumsum%
# 0      Mkt&Fin        120               55.81    55.81
# 1       Mkt&HR         95               44.19   100.00
#
# Frequency Table for mba_p:
#    UniqueValues  Frequency  RelativeFrequency%  Cumsum%
# 0         56.70          3                1.40     1.40
# 1         62.48          2                0.93     2.33
# 2         64.15          2                0.93     3.26
# 3         64.08          2                0.93     4.19
# 4         61.29          2                0.93     5.12
#
# Frequency Table for status:
#   UniqueValues  Frequency  RelativeFrequency%  Cumsum%
# 0       Placed        148               68.84    68.84
# 1   Not Placed         67               31.16   100.00
#
# Frequency Table for salary:
#    UniqueValues  Frequency  RelativeFrequency%  Cumsum%
# 0      300000.0         22               10.23    10.23
# 1      250000.0         18                8.37    18.60
# 2      240000.0         15                6.98    25.58
# 3      390000.0         15                6.98    32.56
# 4      260000.0          7                3.26    35.82
