# %%
import pandas as pd
from data_analysis_utils import Univariate

# %%
data = pd.read_csv('Placement.csv')
quan, qual = Univariate.quanQual(data)

print(quan, qual)
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'] ['gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation', 'status']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %% [markdown]
# # Central Tendency and Location of Data
#
# ### Mean, Mode, Median, Percentile, IQR

# %%
descriptive = Univariate.descriptive(data, quan)

print(descriptive)
# Out:
#                   sl_no  ssc_p  hsc_p degree_p etest_p   mba_p     salary
# Mean              108.0   67.3  66.33    66.37    72.1   62.28  288655.41
# Mode                  1   62.0   63.0     65.0    60.0    56.7   300000.0
# Min                   1  40.89   37.0     50.0    50.0   51.21   200000.0
# Q1-25th%           54.5   60.6   60.9     61.0    60.0  57.945   240000.0
# Median / Q2-50%   108.0   67.0   65.0     66.0    71.0    62.0   265000.0
# Q3-75th%          161.5   75.7   73.0     72.0    83.5  66.255   300000.0
# 99th%            212.86   87.0  91.86    83.86    97.0   76.11        NaN
# Max-100th%          215   89.4   97.7     91.0    98.0   77.89   940000.0
# IQR               107.0   15.1   12.1     11.0    23.5    8.31    60000.0
# 1.5rule           160.5  22.65  18.15     16.5   35.25  12.465    90000.0
# LesserRange      -106.0  37.95  42.75     44.5   24.75   45.48   150000.0
# GreaterRange      322.0  98.35  91.15     88.5  118.75   78.72   390000.0

# %%
descriptive, lesser, greater = Univariate.detect_outliers(descriptive, quan)

print(lesser, greater)
print(descriptive)
# Out:
# ['hsc_p'] ['hsc_p', 'degree_p', 'salary']
#                   sl_no  ssc_p  hsc_p degree_p etest_p   mba_p     salary
# Mean              108.0   67.3  66.33    66.37    72.1   62.28  288655.41
# Mode                  1   62.0   63.0     65.0    60.0    56.7   300000.0
# Min                   1  40.89   37.0     50.0    50.0   51.21   200000.0
# Q1-25th%           54.5   60.6   60.9     61.0    60.0  57.945   240000.0
# Median / Q2-50%   108.0   67.0   65.0     66.0    71.0    62.0   265000.0
# Q3-75th%          161.5   75.7   73.0     72.0    83.5  66.255   300000.0
# 99th%            212.86   87.0  91.86    83.86    97.0   76.11        NaN
# Max-100th%          215   89.4   97.7     91.0    98.0   77.89   940000.0
# IQR               107.0   15.1   12.1     11.0    23.5    8.31    60000.0
# 1.5rule           160.5  22.65  18.15     16.5   35.25  12.465    90000.0
# LesserRange      -106.0  37.95  42.75     44.5   24.75   45.48   150000.0
# GreaterRange      322.0  98.35  91.15     88.5  118.75   78.72   390000.0
# LesserOutlier     False  False   True    False   False   False      False
# GreaterOutlier    False  False   True     True   False   False       True

# %%
data = Univariate.remove_outliers(descriptive, data, lesser, greater)

# %%
descriptive_after_change = Univariate.descriptive(data, quan)

descriptive_after_change, lesser, greater = Univariate.detect_outliers(descriptive_after_change, quan)

print(descriptive_after_change)
# Out:
#                   sl_no  ssc_p  hsc_p degree_p etest_p   mba_p     salary
# Mean              108.0   67.3  66.33    66.36    72.1   62.28  277648.65
# Mode                  1   62.0   63.0     65.0    60.0    56.7   300000.0
# Min                   1  40.89  42.75     50.0    50.0   51.21   200000.0
# Q1-25th%           54.5   60.6   60.9     61.0    60.0  57.945   240000.0
# Median / Q2-50%   108.0   67.0   65.0     66.0    71.0    62.0   265000.0
# Q3-75th%          161.5   75.7   73.0     72.0    83.5  66.255   300000.0
# 99th%            212.86   87.0  91.13    83.86    97.0   76.11        NaN
# Max-100th%          215   89.4  91.15     88.5    98.0   77.89   390000.0
# IQR               107.0   15.1   12.1     11.0    23.5    8.31    60000.0
# 1.5rule           160.5  22.65  18.15     16.5   35.25  12.465    90000.0
# LesserRange      -106.0  37.95  42.75     44.5   24.75   45.48   150000.0
# GreaterRange      322.0  98.35  91.15     88.5  118.75   78.72   390000.0
# LesserOutlier     False  False  False    False   False   False      False
# GreaterOutlier    False  False  False    False   False   False      False
